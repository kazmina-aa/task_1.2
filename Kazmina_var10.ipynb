# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('var10.csv', index_col=0)

# %%
data
# Out:
#          xyxdk      jgiau      jbawc
# 0    14.345921   5.124124   2.879166
# 1    13.763649  19.249921   7.447895
# 2    15.548351  14.139951  10.853053
# 3    -0.866023   5.957933  14.488680
# 4    11.874852   4.332491  13.449729
# ..         ...        ...        ...
# 95    8.361135  15.953557   5.160380
# 96   14.502157   4.953041  10.516942
# 97   17.488193  16.193372  10.959882
# 98   12.494408  11.631063   6.429460
# 99 -136.278976  13.075543  13.719902
#
# [100 rows x 3 columns]

# %%
print(data['xyxdk'].mean(), data['jgiau'].mean(),data['jbawc'].mean())
print(data['xyxdk'].std(), data['jgiau'].std(),data['jbawc'].std())
# Out:
# 9.270295880188463 12.541863378117682 9.540037035307508
# 22.541310336497887 4.849478111365082 19.381400154112043

# %%
plt.plot(data['xyxdk'])

# %%
plt.plot(data['jgiau'])

# %%
plt.plot(data['jbawc'])

# %%
plt.plot(data['xyxdk'],data['jgiau'])

# %%
plt.plot(data['xyxdk'],data['jbawc'])

# %%
plt.plot(data['jgiau'],data['jbawc'])

# %%
plt.hist(data['xyxdk'])
# Out:
# (array([ 1.,  1.,  0.,  0.,  0., 96.,  1.,  0.,  0.,  1.]),
#  array([-136.27897551, -110.13006086,  -83.98114621,  -57.83223156,
#          -31.68331691,   -5.53440225,   20.6145124 ,   46.76342705,
#           72.9123417 ,   99.06125635,  125.210171  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['jgiau'])
# Out:
# (array([ 4.,  8., 12., 14., 22., 17., 11.,  8.,  3.,  1.]),
#  array([ 1.69960613,  4.11010903,  6.52061192,  8.93111482, 11.34161771,
#         13.75212061, 16.1626235 , 18.5731264 , 20.98362929, 23.39413219,
#         25.80463508]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['jbawc'])
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0.,  0.,  1., 25., 72.]),
#  array([-126.91728159, -111.75752376,  -96.59776592,  -81.43800809,
#          -66.27825025,  -51.11849242,  -35.95873459,  -20.79897675,
#           -5.63921892,    9.52053892,   24.68029675]),
#  <BarContainer object of 10 artists>)

# %%
arr = data.to_numpy()
plt.hist(arr)
for i in range(arr.shape[0]):
    for j in range(arr.shape[1]):
        if abs(arr[i,j])>2*abs(arr[i].mean()):
            np.delete(arr,[i,j])

# %%
plt.hist(arr)
#я не знаю почему не получилось:()
# Out:
# (array([[ 1.,  1.,  0.,  0.,  0., 96.,  1.,  0.,  0.,  1.],
#         [ 0.,  0.,  0.,  0.,  0., 96.,  4.,  0.,  0.,  0.],
#         [ 2.,  0.,  0.,  0.,  1., 92.,  5.,  0.,  0.,  0.]]),
#  array([-136.27897551, -110.13006086,  -83.98114621,  -57.83223156,
#          -31.68331691,   -5.53440225,   20.6145124 ,   46.76342705,
#           72.9123417 ,   99.06125635,  125.210171  ]),
#  <a list of 3 BarContainer objects>)

# %%
arr.mean(), arr.std()
# Out:
# (10.450732097871219, 17.366536201837746)
